# %%
Version Control System:

# %%
print("Hello Github... Start using git repo in my local")
# Out:
# Hello Github... Start using git repo in my local

# %%
a=121
print(a)
# Out:
# 121

# %%
a
# Out:
# 121
